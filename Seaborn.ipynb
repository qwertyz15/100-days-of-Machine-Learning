# %% [markdown]
# # <h1 style="color:red;"> <i> <strong> SEABORN PRACTICE </strong> </i></h1>

# %% [markdown]
# # Distribution plots
#     1.distplot
#     2.joinplot
#     3.pairplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# # Correlation with Heatmap

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['tip'])

# %%
sns.distplot(df['tip'],kde = False,bins = 10)

# %%
sns.distplot(df['total_bill'],kde = False,bins = 10)

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = 'hex')

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = 'reg')

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# # Categorical Plots
#     1.Count Plot
#     2.Bar Plot
#     3.Box Plot
#     4.Violin Plot

# %% [markdown]
# ## Count Plot

# %%
sns.countplot('sex', data = df)

# %%
sns.countplot(y = 'sex', data = df)

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(x = 'sex', y = 'size', data = df)

# %%
sns.catplot(x = 'sex', y = 'size', data = df, kind = 'bar')

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x = 'tip', y = 'sex', data = df)

# %%
sns.catplot(x = 'tip', y = 'sex', data = df, kind = 'box')

# %%
sns.catplot(data = df, kind = 'box', orient = 'v')

# %%
sns.catplot(x = 'tip', y = 'sex', data = df, kind = 'box', hue = 'day')

# %%
sns.catplot(x = 'tip', y = 'sex', data = df, kind = 'box', hue = 'day', row = 'smoker')

# %%
sns.catplot(x = 'tip', y = 'sex', data = df, kind = 'box', hue = 'day', col = 'smoker')

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x = 'tip', y = 'sex', data = df)

# %%
sns.catplot(x = 'tip', y = 'sex', data = df, kind = 'violin')
